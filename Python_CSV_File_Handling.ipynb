# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti199/basicCoding/blob/main/Python_CSV_File_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
with open("Name_rollno.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "emailid", "game", "Age"])
    writer.writerow(["Jyoti", "sharma001jyoti@gmail.com", "Basketball", 22])
    writer.writerow(["puja", "puja@gmail.com", "Vollyball", 23])
    writer.writerow(["Mona", "mona@gmail.com", "Football", 21])
    writer.writerow(["Puchkii", "puchki@gmail.com", "badminton", 20])
    writer.writerow(["Ram", "ram@gmail.com", "Cricket", 24])
print("CSV file created successfully.")
# Out:
# CSV file created successfully.
