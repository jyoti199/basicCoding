# %% [markdown]
# <a href="https://colab.research.google.com/github/jyoti199/basicCoding/blob/main/Python_SQLite_Database_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
conn=sqlite3.connect("name_rollno.db")
cursor=conn.cursor()
cursor.executescript('''
                     DROP TABLE IF EXISTS Student_info;
                     CREATE TABLE Student_info(
                         rollno INT PRIMARY KEY,
                         name VARCHAR(100),
                         emailid VARCHAR(100),
                         game VARCHAR(50)
                     );
                     INSERT INTO Student_info VALUES(1,'jyoti sharma','sharma001jyoti@gmail.com','badminton');
                     INSERT INTO Student_info VALUES(2,'mona','monaSharma@gmail.com','tennis');
                      INSERT INTO Student_info VALUES(3,'seema sharma','sharmaseema@gmail.com','chess');
                     INSERT INTO Student_info VALUES(4,'vivek','vivekSharma@gmail.com','football');
                      INSERT INTO Student_info VALUES(5,'vikash','sharmavikash@gmail.com','basketball');
                     INSERT INTO Student_info VALUES(6,'vinay','vinaySharma@gmail.com','cricket');

                     ''')
print("Students with odd roll numbers:")
cursor.execute("SELECT * FROM Student_info WHERE rollno%2 !=0;")
for row in cursor.fetchall():
  print(row)
print("\nStudents with even roll numbers:")
cursor.execute("SELECT * FROM Student_info WHERE rollno%2=0;")
for row in cursor.fetchall():
  print(row)
# Out:
# Students with odd roll numbers:
# (1, 'jyoti sharma', 'sharma001jyoti@gmail.com', 'badminton')
# (3, 'seema sharma', 'sharmaseema@gmail.com', 'chess')
# (5, 'vikash', 'sharmavikash@gmail.com', 'basketball')
#
# Students with even roll numbers:
# (2, 'mona', 'monaSharma@gmail.com', 'tennis')
# (4, 'vivek', 'vivekSharma@gmail.com', 'football')
# (6, 'vinay', 'vinaySharma@gmail.com', 'cricket')
